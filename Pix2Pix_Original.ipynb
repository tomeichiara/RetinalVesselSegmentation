# %% [markdown]
# #Import & Function

# %%
from numpy import zeros
from numpy import ones
from numpy.random import randint
from keras.initializers import RandomNormal
from keras.models import Model
from keras.models import Input
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from matplotlib import pyplot as plt
from tensorflow.keras.utils import plot_model
from keras import backend as K
from sklearn.model_selection import train_test_split

import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2
import shutil
import itertools
import random

from numpy import asarray, load
from numpy import vstack
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import savez_compressed
from matplotlib import pyplot

from tensorflow import keras
#from tensorflow.keras import layers
from keras.models import load_model
from tensorflow.keras.metrics import MeanIoU
from os import listdir
from os.path import isfile, join
from PIL import Image
from pathlib import Path
from skimage.color import rgb2gray
from datetime import datetime

# %%
def flatten(listOfLists):
    "Flatten one level of nesting"
    return list(itertools.chain.from_iterable(listOfLists))

# %%
def searching_all_files(directory: Path):   
    file_list = [] # A list for storing files existing in directories

    for x in directory.iterdir():
        if x.is_file():

           file_list.append(str(x))
        else:

           file_list.append(searching_all_files(directory/x))

    return file_list

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Parameters

# %%
lr_generator = 0.0002
beta1_generator = 0.5
beta1_discriminator = 0.5
numero_epoche = 100
numero_batch = 16

dieciEpoche = 900000
cinquantaEpoche = 900000

tanh = True

# %% [markdown]
# #Train & Test

# %%
X_train = np.load('/content/drive/MyDrive/Tesi magistrale/Numpy/X_train_256.npy')
X_test = np.load('/content/drive/MyDrive/Tesi magistrale/Numpy/X_test_256.npy')
y_train = np.load('/content/drive/MyDrive/Tesi magistrale/Numpy/y_train_256.npy')
y_test = np.load('/content/drive/MyDrive/Tesi magistrale/Numpy/y_test_256.npy')

# %%
#Sanity check, view few mages
import random

image_number = random.randint(0, len(X_train)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_train[image_number,:,:,0],cmap = 'gray')
plt.subplot(122)
plt.imshow(y_train[image_number,:,:,0],cmap = 'gray')
plt.show()

# %%
#Define data
# load and prepare training images
data = [X_train, y_train]
data_test = [X_test,y_test]

# %%
def preprocess_data(data):
  # load compressed arrays
  # unpack arrays
  X1, X2 = data[0], data[1]
  # scale from [0,255] to [-1,1]
  X1 = X1*255
  X2 = X2*255
  X1 = (X1 - 127.5) / 127.5
  X2 = (X2 - 127.5) / 127.5
  return [X1, X2]

if tanh:
  data = preprocess_data(data)
  data_test = preprocess_data(data_test)

# %% [markdown]
# #Pix2Pix

# %%
def jacard_coef(y_true, y_pred):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def jacard_coef_loss(y_true, y_pred):
  return -jacard_coef(y_true, y_pred)

# %%
def define_discriminator(image_shape,target_shape):
    
	# weight initialization
	init = RandomNormal(stddev=0.02,seed = 1305) #As described in the original paper
    
	# source image input
	in_src_image = Input(shape=image_shape)  #Image we want to convert to another image
	# target image input
	in_target_image = Input(shape=target_shape)  #Image we want to generate after training
    
	# concatenate images, channel-wise
	merged = Concatenate()([in_src_image, in_target_image])
    
	# C64: 4x4 kernel Stride 2x2
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
	d = LeakyReLU(alpha=0.2)(d)
	# C128: 4x4 kernel Stride 2x2
	d = Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256: 4x4 kernel Stride 2x2
	d = Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C512: 4x4 kernel Stride 2x2 
  
	d = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer : 4x4 kernel but Stride 1x1
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	d = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	patch_out = Activation('sigmoid')(d)
	# define model
	model = Model([in_src_image, in_target_image], patch_out)
	# compile model
    #The model is trained with a batch size of one image and Adam opt. 
    #with a small learning rate and 0.5 beta. 
    #The loss for the discriminator is weighted by 50% for each model update.
    
	opt = keras.optimizers.Adam(learning_rate=0.0002,beta_1=beta1_discriminator)
	model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
	return model

# %%
disc_model = define_discriminator((256,256,1),(256,256,1))
#plot_model(disc_model, to_file='disc_model.png', show_shapes=True)

# %%
def define_encoder_block(layer_in, n_filters, batchnorm=True):
	# weight initialization
	init = RandomNormal(stddev=0.02,seed = 1305)
	# add downsampling layer
	g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# conditionally add batch normalization
	if batchnorm:
		g = BatchNormalization()(g, training=True)
	# leaky relu activation
	g = LeakyReLU(alpha=0.2)(g)
	return g

# define a decoder block to be used in generator
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
	# weight initialization
	init = RandomNormal(stddev=0.02,seed = 42)
	print("Encoding",layer_in)
	# add upsampling layer
	g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	print("Encoding_Conv",g)
	# add batch normalization
	g = BatchNormalization()(g, training=True)
	print("Encoding_Batch",g)
	# conditionally add dropout
	if dropout:
		g = Dropout(0.5)(g, training=True)
		print("Encoding_Drop",g)
	# merge with skip connection
	g = Concatenate()([g, skip_in])
	print("Encoding_Drop",g)
	# relu activation
	g = Activation('relu')(g)
	return g

# define the standalone generator model - U-net
def define_generator(image_shape=(256,256,1), target_shape=(256,256,1)):
	# weight initialization
	init = RandomNormal(stddev=0.02, seed = 1305)
	# image input
	in_image = Input(shape=image_shape)
	#print(in_image)
	# encoder model: C64-C128-C256-C512-C512-C512-C512-C512
	e1 = define_encoder_block(in_image, 64, batchnorm=False)
	#print(e1)
	e2 = define_encoder_block(e1, 128)
	#print(e2)
	e3 = define_encoder_block(e2, 256)
	#print(e3)
	e4 = define_encoder_block(e3, 512)
	#print(e4)
	e5 = define_encoder_block(e4, 512)
	#print(e5)
	e6 = define_encoder_block(e5, 512)
	#print(e6)
	e7 = define_encoder_block(e6, 512)
	#print(e7)
	# bottleneck, no batch norm and relu
	b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
	#print(b)
	b = Activation('relu')(b)
	#print(b)
	# decoder model: CD512-CD512-CD512-C512-C256-C128-C64
	d1 = decoder_block(b, e7, 512)
	#print(d1)
	d2 = decoder_block(d1, e6, 512)
	#print(d2)
	d3 = decoder_block(d2, e5, 512)
	#print(d3)
	d4 = decoder_block(d3, e4, 512, dropout=False)
	#print(d4)
	d5 = decoder_block(d4, e3, 256, dropout=False)
	#print(d5)
	d6 = decoder_block(d5, e2, 128, dropout=False)
	d7 = decoder_block(d6, e1, 64, dropout=False)
	# output
	g = Conv2DTranspose(target_shape[2], (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7) #Modified 
	out_image = Activation('tanh')(g)  #Generates images in the range -1 to 1 
	# define model
	model = Model(in_image, out_image)
	return model

# %%
gen_model = define_generator((256,256,1),(256,256,1))
#plot_model(gen_model, to_file='gen_model.png', show_shapes=True)
# Out:
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 512), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='conv2d_transpose/BiasAdd:0', description="created by layer 'conv2d_transpose'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='batch_normalization_10/FusedBatchNormV3:0', description="created by layer 'batch_normalization_10'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='dropout/dropout/Mul_1:0', description="created by layer 'dropout'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 1024), dtype=tf.float32, name=None), name='concatenate_1/concat:0', description="created by layer 'concatenate_1'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 1024), dtype=tf.float32, name=None), name='activation_2/Relu:0', description="created by layer 'activation_2'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 512), dtype=tf.float32, name=None), name='conv2d_transpose_1/BiasAdd:0', description="created by layer 'conv2d_transpose_1'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 512), dtype=tf.float32, name=None), name='batch_normalization_11/FusedBatchNormV3:0', description="created by layer 'batch_normalization_11'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 512), dtype=tf.float32, name=None), name='dropout_1/dropout/Mul_1:0', description="created by layer 'dropout_1'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1024), dtype=tf.float32, name=None), name='concatenate_2/concat:0', description="created by layer 'concatenate_2'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1024), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='conv2d_transpose_2/BiasAdd:0', description="created by layer 'conv2d_transpose_2'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='batch_normalization_12/FusedBatchNormV3:0', description="created by layer 'batch_normalization_12'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='dropout_2/dropout/Mul_1:0', description="created by layer 'dropout_2'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='concatenate_3/concat:0', description="created by layer 'concatenate_3'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='activation_4/Relu:0', description="created by layer 'activation_4'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 512), dtype=tf.float32, name=None), name='conv2d_transpose_3/BiasAdd:0', description="created by layer 'conv2d_transpose_3'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 512), dtype=tf.float32, name=None), name='batch_normalization_13/FusedBatchNormV3:0', description="created by layer 'batch_normalization_13'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 1024), dtype=tf.float32, name=None), name='concatenate_4/concat:0', description="created by layer 'concatenate_4'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 1024), dtype=tf.float32, name=None), name='activation_5/Relu:0', description="created by layer 'activation_5'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 256), dtype=tf.float32, name=None), name='conv2d_transpose_4/BiasAdd:0', description="created by layer 'conv2d_transpose_4'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 256), dtype=tf.float32, name=None), name='batch_normalization_14/FusedBatchNormV3:0', description="created by layer 'batch_normalization_14'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 512), dtype=tf.float32, name=None), name='concatenate_5/concat:0', description="created by layer 'concatenate_5'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 512), dtype=tf.float32, name=None), name='activation_6/Relu:0', description="created by layer 'activation_6'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 128), dtype=tf.float32, name=None), name='conv2d_transpose_5/BiasAdd:0', description="created by layer 'conv2d_transpose_5'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 128), dtype=tf.float32, name=None), name='batch_normalization_15/FusedBatchNormV3:0', description="created by layer 'batch_normalization_15'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 256), dtype=tf.float32, name=None), name='concatenate_6/concat:0', description="created by layer 'concatenate_6'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 256), dtype=tf.float32, name=None), name='activation_7/Relu:0', description="created by layer 'activation_7'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 64), dtype=tf.float32, name=None), name='conv2d_transpose_6/BiasAdd:0', description="created by layer 'conv2d_transpose_6'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 64), dtype=tf.float32, name=None), name='batch_normalization_16/FusedBatchNormV3:0', description="created by layer 'batch_normalization_16'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 128), dtype=tf.float32, name=None), name='concatenate_7/concat:0', description="created by layer 'concatenate_7'")

# %%
def define_gan(g_model, d_model, image_shape):
	# make weights in the discriminator not trainable
	for layer in d_model.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False       #Descriminator layers set to untrainable in the combined GAN but 
                                                #standalone descriminator will be trainable.
            
	# define the source image
	in_src = Input(shape=image_shape)
	# suppy the image as input to the generator 
	gen_out = g_model(in_src)
	# supply the input image and generated image as inputs to the discriminator
	dis_out = d_model([in_src, gen_out])
	# src image as input, generated image and disc. output as outputs
	model = Model(in_src, [dis_out, gen_out])
	# compile model
	opt = keras.optimizers.Adam(learning_rate=lr_generator,beta_1=beta1_generator)
    
    #Total loss is the weighted sum of adversarial loss (BCE) and L1 loss (MAE)
    #Authors suggested weighting BCE vs L1 as 1:100.
	model.compile(loss=['binary_crossentropy', "mae"], 
               optimizer=opt, loss_weights=[1,100])
	return model

# %%
# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
	# unpack dataset
	trainA, trainB = dataset
	# choose random instance

	np.random.seed(1305)
	ix = np.random.randint(0, trainA.shape[0], n_samples)
	# retrieve selected images
	X1, X2 = trainA[ix], trainB[ix]
	# generate 'real' class labels (1)
	y = ones((n_samples, patch_shape, patch_shape, 1))
	return [X1, X2], y

# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
	# generate fake instance
	X = g_model.predict(samples)
	# create 'fake' class labels (0)
	y = zeros((len(X), patch_shape, patch_shape, 1))
	return X, y

# %% [markdown]
# #Salvataggio modello

# %%
def summarize_performance(step, g_model, dataset, n_samples=3):
	# select a sample of input images
	[X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
	# generate a batch of fake samples
	X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
 
 	# scale all pixels from [-1,1] to [0,1]
	X_realA = (X_realA + 1) / 2.0
	X_realB = (X_realB + 1) / 2.0
	X_fakeB = (X_fakeB + 1) / 2.0
	
	# plot real source images
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + i)
		plt.axis('off')
		plt.imshow(X_realA[i][:,:,0],cmap='gray')
	# plot generated target image
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + n_samples + i)
		plt.axis('off')
		plt.imshow(X_fakeB[i][:,:,0],cmap='gray')
	# plot real target image
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + n_samples*2 + i)
		plt.axis('off')
		plt.imshow(X_realB[i][:,:,0],cmap='gray')
	# save plot to file
	filename1 = '/content/drive/MyDrive/Tesi magistrale/modelli_salvati/Pix2Pix_Original_100Epoche_B16_%01d.png' % (step+1)

	plt.savefig(filename1)
	plt.close()
	# save the generator model
	filename2 = '/content/drive/MyDrive/Tesi magistrale/modelli_salvati/Pix2Pix_Original_100_Epoche_B16_%01d.hdf5' % (step+1)
	g_model.save(filename2)
	print('Saved')

# %%
# train pix2pix models
def train(d_model, g_model, gan_model, dataset, n_epochs=100, n_batch=1, dieciEpoche=120, cinquantaEpoche=600):
  # determine the output square shape of the discriminator
  n_patch = d_model.output_shape[1] #16
  # unpack dataset
  trainA, trainB = dataset
  # calculate the number of batches per training epoch
  bat_per_epo = int(len(trainA) / n_batch)
  # calculate the number of training iterations
  n_steps = bat_per_epo * n_epochs
  # manually enumerate epochs
  for i in range(n_steps):
    # select a batch of real samples
    [X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
    # generate a batch of fake samples
    X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
    # update discriminator for real samples
    d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
    # update discriminator for generated samples
    d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
    # update the generator
    g1_loss, g2_loss, g3_loss = gan_model.train_on_batch(X_realA, [y_real, X_realB])
    
    if ((i+1) % (bat_per_epo * 10) == 0) or ((i+1)==dieciEpoche) or((i+1)==cinquantaEpoche):
      print('>%d, d1[%.3f] d2[%.3f] g1[%.3f] g2[%.3f] g3[%.3f]' % (i+1, d_loss1, d_loss2, g1_loss, g2_loss, g3_loss))
      summarize_performance(i, g_model, dataset)

# %% [markdown]
# #Train model

# %%
image_shape = X_train[0].shape
target_shape = y_train[0].shape

# %%
image_shape
# Out:
# (256, 256, 1)

# %%
d_model = define_discriminator(image_shape,target_shape)
g_model = define_generator(image_shape,target_shape)
# define the composite model
gan_model = define_gan(g_model, d_model, image_shape)
# Out:
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, 512), dtype=tf.float32, name=None), name='activation_11/Relu:0', description="created by layer 'activation_11'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='conv2d_transpose_8/BiasAdd:0', description="created by layer 'conv2d_transpose_8'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='batch_normalization_27/FusedBatchNormV3:0', description="created by layer 'batch_normalization_27'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='dropout_3/dropout/Mul_1:0', description="created by layer 'dropout_3'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 1024), dtype=tf.float32, name=None), name='concatenate_9/concat:0', description="created by layer 'concatenate_9'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 1024), dtype=tf.float32, name=None), name='activation_12/Relu:0', description="created by layer 'activation_12'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 512), dtype=tf.float32, name=None), name='conv2d_transpose_9/BiasAdd:0', description="created by layer 'conv2d_transpose_9'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 512), dtype=tf.float32, name=None), name='batch_normalization_28/FusedBatchNormV3:0', description="created by layer 'batch_normalization_28'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 512), dtype=tf.float32, name=None), name='dropout_4/dropout/Mul_1:0', description="created by layer 'dropout_4'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1024), dtype=tf.float32, name=None), name='concatenate_10/concat:0', description="created by layer 'concatenate_10'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1024), dtype=tf.float32, name=None), name='activation_13/Relu:0', description="created by layer 'activation_13'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='conv2d_transpose_10/BiasAdd:0', description="created by layer 'conv2d_transpose_10'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='batch_normalization_29/FusedBatchNormV3:0', description="created by layer 'batch_normalization_29'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='dropout_5/dropout/Mul_1:0', description="created by layer 'dropout_5'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='concatenate_11/concat:0', description="created by layer 'concatenate_11'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='activation_14/Relu:0', description="created by layer 'activation_14'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 512), dtype=tf.float32, name=None), name='conv2d_transpose_11/BiasAdd:0', description="created by layer 'conv2d_transpose_11'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 512), dtype=tf.float32, name=None), name='batch_normalization_30/FusedBatchNormV3:0', description="created by layer 'batch_normalization_30'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 1024), dtype=tf.float32, name=None), name='concatenate_12/concat:0', description="created by layer 'concatenate_12'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 1024), dtype=tf.float32, name=None), name='activation_15/Relu:0', description="created by layer 'activation_15'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 256), dtype=tf.float32, name=None), name='conv2d_transpose_12/BiasAdd:0', description="created by layer 'conv2d_transpose_12'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 256), dtype=tf.float32, name=None), name='batch_normalization_31/FusedBatchNormV3:0', description="created by layer 'batch_normalization_31'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 512), dtype=tf.float32, name=None), name='concatenate_13/concat:0', description="created by layer 'concatenate_13'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 512), dtype=tf.float32, name=None), name='activation_16/Relu:0', description="created by layer 'activation_16'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 128), dtype=tf.float32, name=None), name='conv2d_transpose_13/BiasAdd:0', description="created by layer 'conv2d_transpose_13'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 128), dtype=tf.float32, name=None), name='batch_normalization_32/FusedBatchNormV3:0', description="created by layer 'batch_normalization_32'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 256), dtype=tf.float32, name=None), name='concatenate_14/concat:0', description="created by layer 'concatenate_14'")
# Encoding KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 256), dtype=tf.float32, name=None), name='activation_17/Relu:0', description="created by layer 'activation_17'")
# Encoding_Conv KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 64), dtype=tf.float32, name=None), name='conv2d_transpose_14/BiasAdd:0', description="created by layer 'conv2d_transpose_14'")
# Encoding_Batch KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 64), dtype=tf.float32, name=None), name='batch_normalization_33/FusedBatchNormV3:0', description="created by layer 'batch_normalization_33'")
# Encoding_Drop KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 128), dtype=tf.float32, name=None), name='concatenate_15/concat:0', description="created by layer 'concatenate_15'")

# %%
start1 = datetime.now() 

train(d_model, g_model, gan_model, data, n_epochs=numero_epoche, n_batch=numero_batch, dieciEpoche=dieciEpoche, cinquantaEpoche=cinquantaEpoche) 

stop1 = datetime.now()
#Execution time of the model 
execution_time = stop1-start1
print("Execution time is: ", execution_time)
# Out:
# >100, d1[0.017] d2[0.018] g1[17.963] g2[4.044] g3[0.139]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >200, d1[0.168] d2[0.139] g1[7.863] g2[2.235] g3[0.056]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >300, d1[0.280] d2[0.215] g1[6.188] g2[2.735] g3[0.035]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >400, d1[0.020] d2[0.026] g1[6.773] g2[3.961] g3[0.028]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >500, d1[0.067] d2[0.087] g1[4.324] g2[2.825] g3[0.015]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >600, d1[0.361] d2[0.269] g1[3.963] g2[2.704] g3[0.013]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >700, d1[0.104] d2[0.114] g1[4.804] g2[3.453] g3[0.014]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >800, d1[0.671] d2[0.161] g1[3.870] g2[2.624] g3[0.012]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >900, d1[0.057] d2[0.067] g1[4.513] g2[3.131] g3[0.014]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# >1000, d1[0.061] d2[0.066] g1[4.200] g2[3.216] g3[0.010]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved
# Execution time is:  0:12:03.230099

# %% [markdown]
# #Results

# %%
model = load_model('/content/drive/MyDrive/Tesi magistrale/modelli_salvati/Pix2Pix_Original_100_Epoche_B16_500.hdf5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
threshold = 0.5
[X_test, y_test] = data_test
y_pred = model.predict(X_test)
y_pred = (y_pred + 1) / 2.0
y_test = (y_test + 1) / 2.0
X_test = (X_test + 1) / 2.0
y_pred_thresholded = y_pred > threshold

# %%
#____________ MEAN IOU__________________
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_pred_thresholded, y_test)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.6569364

# %%
#_____________ IOU____________________
intersection = np.logical_and(y_test,y_pred_thresholded)
union=np.logical_or(y_test,y_pred_thresholded)
iou_score = np.sum(intersection)/np.sum(union)
print("IoU score is:",iou_score)
# Out:
# IoU score is: 0.3571693713967543

# %%
#_____________ DICE____________________
intersection = np.logical_and(y_test,y_pred_thresholded)
union=np.logical_or(y_test,y_pred_thresholded)
dice_score = (2*np.sum(intersection))/(np.sum(union)+np.sum(intersection))
print("Dice score is:", dice_score)
# Out:
# Dice score is: 0.5263445800123935

# %%
test_img_number = random.randint(0, len(X_test)-1)
#test_img_number = 1
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > threshold).astype(np.uint8)


plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)

plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %% [markdown]
# #Overlapping

# %%
fig, ax = plt.subplots()
ax.imshow(ground_truth[:,:,0], cmap='gray')
ax.imshow(prediction,cmap='gray', alpha=0.6)
fig.show()

# %% [markdown]
# # Plot all test images

# %%
def plot_images(test_images, ground_truth, prediction, i):
  plt.figure()
  i = i+1
  titolo = 'Testing Image '+str(i)
  plt.title(titolo)
  plt.imshow(test_img[:,:,0], cmap='gray')
  plt.show()

def plot_overlapping(ground_truth, prediction, i):
  fig, ax = plt.subplots()
  ax.imshow(ground_truth[:,:,0], cmap='gray')
  ax.imshow(prediction,cmap='gray', alpha=0.6)
  i = i+1
  titolo = 'Masks Overlapping '+str(i)
  ax.set_title(titolo)
  fig.show()

# %%
for i in range(len(X_test)):
  test_img_number = i
  test_img = X_test[test_img_number]
  ground_truth=y_test[test_img_number]
  test_img_input=np.expand_dims(test_img, 0)
  prediction = (model.predict(test_img_input)[0,:,:,0] > threshold).astype(np.uint8)
  
  plot_images(test_img, ground_truth, prediction, i)
  plot_overlapping(ground_truth, prediction, i)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
